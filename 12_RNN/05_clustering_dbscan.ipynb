# %% [markdown]
# # 클러스터링 (Clustering) 실습

# %%
#구글드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# 입력 데이터 위치
Path = '/content/drive/MyDrive/Colab Notebooks/KT_RNN/data/clustering/' 

# 각 주제별 100건의 뉴스 데이터
# Read an Excel file into a pandas DataFrame
# DataFrame : 2차원 데이터구조. Row, Column, Series(각 Column에 있는 데이터들)로 구성
climate = pd.read_excel(Path+'news_climate change.xlsx')
mobility = pd.read_excel(Path+'news_mobility.xlsx')
probiotics = pd.read_excel(Path+'news_probiotics.xlsx')

# 주제 column을 추가
climate['주제'] = '기후위기'
mobility['주제'] = '모빌리티'
probiotics['주제'] = '유산균'

# 각 주제별 70건의 뉴스데이터를 가져와서 입력용 데이터를 생성
# pandas.concat(objs, axis=0, ignore_index=Faslse, ...)
# axis=0, 0: 위+아래로 합치기, 1: 왼쪽+오른쪽으로 합치기
# ignore_index=True : 기존 index를 무시. The resulting axis will be labeled 0, …, n - 1. 
data = pd.concat([climate[:70], mobility[:70], probiotics[:70]], ignore_index=True)

# 뉴스기사 body, title을 기준으로 중복을 제거
# DataFrame.drop_duplicates : Returns DataFrame with duplicate rows removed.
data_unique = data.drop_duplicates(['body']).drop_duplicates(['title'])

# 중복 제거된 데이터 건수를 확인
# DataFrame.shape : Returns a tuple representing the dimensionality of the DataFrame.
data.shape, data_unique.shape
# Out:
# ((210, 5), (198, 5))

# %% [markdown]
# 중복으로 들어있는 기사를 제거하고 기사들의 순서를 무작위로 섞습니다.

# %%
# 데이터 순서를 셔플링
# frac: 랜덤 추출할 비율 (1 == 전체 데이터를 셔플링)
# random_state: 랜덤 추출할 값에 seed 설정하면, 항상 같은 결과를 생성
# reset_index: Reset the index. Use drop parameter to avoid the old index being added as a column
data_shuffled = data_unique.sample(frac=1, random_state=16).reset_index(drop=True) 
data_shuffled.head(3)
# Out:
#                   date                                  title  \
# 0  2022-08-26 14:36:00  '자율주행차에서 브레이크 고장나면?'…현대차그룹, 대응 시스템 공개
# 1  2022-08-16 19:50:00    미-러 핵전쟁 시 50억명 이상 굶어 죽는다"" 美 연구팀 발표
# 2  2022-08-29 20:07:00         [여기는 전남] 전남도, 적조 피해 예방 총력 대응 외
#
#                                                 body channel    주제
# 0  [자료=현대자동차] 현대차그룹이 오늘(26일) 특허 출원한 자율주행 차량의 브레이크...    news  모빌리티
# 1  미국과 러시아가 핵전쟁을 할 경우 전 세계 50억명 이상의 사람이 굶주림으로 숨질 ...    news  기후위기
# 2  [KBS 광주]고흥 외나로도에서 여수 돌산 해역까지 적조 주의보가 내려진 가운데 전...    news  기후위기

# %%
# DataFrame.iloc : integer-location based indexing for selection by position
data_shuffled.iloc[0]['title']
data_shuffled.iloc[0]['body']
# Out:
# '[자료=현대자동차] 현대차그룹이 오늘(26일) 특허 출원한 자율주행 차량의 브레이크 고장 대응 시스템 을 HMG 테크 사이트 에 공개했습니다. 현대차그룹은 해당 기술이 완전 자율주행 모빌리티를 전제로 하며, 브레이크 장치에 오류가 발생하는 예기치 못한 상황에서 다른 차량 간의 상호작용으로 피해를 최소화하는 사고 대응 기술이라고 설명했습니다. 브레이크 고장 시스템으로, 자율주행 차량이 주행 도중 제동이 필요한 상황에서 전자 제어장치를 통해 메인 제동 장치의 작동을 확인하고, 반응이 없으면 전자 제어장치는 다시 한번 보조 제동 장치를 거쳐 제동 가능 여부를 판별합니다. 이때 보조 제동 장치까지 사용이 불가능하다고 판단되면 전자 제어장치는 가장 가까운 자율주행 관제시스템을 향해 제동 시스템에 문제가 있다는 신호를 전달합니다. 정보를 전달받은 관제시스템은 고장 차량과 가장 가까이에서 주행 중인 차량에게 구조 신호를 보냅니다. 신호를 수신한 자율주행 차량은 고장 차량을 안전하게 정지시키기 위해 고장 차량이 관제시스템에게 전달한 정보를 토대로 조향 시스템을 제어합니다. 또한, 구조 진행 상황을 관제시스템에게 전달함과 동시에 고장 차량과 같은 차선으로 주행하도록 접근합니다. 관제시스템은 고장 차량의 무사 처리를 위해 주변 차량들이 해당 차선에 주행하지 않도록 지시합니다. 같은 차선으로 이동한 차량은 주행 속도와 조향 시스템을 꾸준히 조절하며 고장 차량의 범퍼에 접촉해 차량의 속도를 서서히 줄입니다. 꾸준한 차량 제어로 고장 차량이 완전히 멈추면 관제시스템에 구조 완료 신호를 보낸 후 구조 작업을 끝냅니다. 무선 통신을 거쳐 주변 차량과의 상호작용으로 사고를 완화하는 것입니다. 현대차그룹은 "브레이크 고장 대응 시스템 기술에 대한 특허를 미국, 중국, 한국에 출원했으며, 가능성이 희박한 만약의 상황까지 고려한 전방위 안전 체계를 구축하기 위해 자율주행 기술의 기초부터 완성도를 꾸준히 높여가고 있다"고 말했습니다.'

# %% [markdown]
# 먼저 형태소 분석을 하기 위해 konlpy를 설치합니다.

# %%
# 한국어 형태소 분석기를 포함하고 있는 파이썬 패키지 설치
# !pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 1.3 MB/s
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.4.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (453 kB)
#      |████████████████████████████████| 453 kB 56.5 MB/s
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.9.1)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.21.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (4.1.1)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.0 konlpy-0.6.0

# %% [markdown]
# ##**< 뉴스 기사 단어 빈도 분석 >**

# %% [markdown]
# 오픈소스 한국어 형태소분석기 중 하나인 Hannanum 패키지를 import하고 클래스 객체를 생성합니다.
#
# 빈 리스트를 하나 만들고 `hannanum` 클래스를 이용해 명사만을 추출하여 저장합니다.

# %%
# 데이터에서 첫번째 기사 내용을 가져와서 명사만 추출합니다
from konlpy.tag import Hannanum
hannanum = Hannanum()

temp = hannanum.nouns(data_shuffled.loc[0]['body'])
print(temp)
# Out:
# ['[자료=현대자동차]', '현대차그룹', '오늘(26일)', '특허', '출원', '자율주행', '차량', '브레이크', '고장', '대응', '시스템', '을', '테크', '사이트', '공개', '현대차그룹', '해당', '기술', '완전', '자율주행', '모빌리티', '전제', '브레이크', '장치', '오류', '발생', '예기치', '상황', '차량', '간', '상호작용', '피해', '최소', '대응', '기술', '설명', '브레이크', '고장', '시스템', '자율주행', '차량', '주행', '도중', '제동', '필요', '상황', '전자', '제어장치', '제동', '장치', '작동', '확인', '반응', '전자', '제어장치', '한번', '보조', '제동', '장치', '제동', '가능', '여부', '판별', '이때', '보조', '제동', '장치', '사용', '불가능', '판단', '전자', '제어장치', '자율주행', '관제시스템', '제동', '시스템', '문제', '신호', '전달', '정보', '전달', '관제시스템', '고장', '차량', '가까이', '주행', '중', '차량', '구조', '신호', '신호', '수', '한', '자율주행', '차량', '고장', '차량', '안전', '정지', '고장', '차량', '관제시스템', '전달한', '정보', '토대', '조향', '시스템', '제', '구조', '진행', '상황', '관제시스템', '전달함', '고장', '차량', '차선', '주행', '접근', '관제시스템', '고장', '차량', '무사', '처리', '주변', '차량들', '해당', '차선', '주행', '지시', '차선', '이동한', '차량', '주행', '속도', '조향', '시스템', '조절', '고장', '차량', '범퍼', '접촉', '차량', '속도', '줄', '한', '차량', '제어', '고장', '차량', '관제시스템', '구조', '완료', '신호', '후', '구조', '작업', '무선', '통신', '주변', '차량', '상호작용', '사고', '완화', '것', '현대차그룹', '브레이크', '고장', '대응', '시스템', '기술', '특허', '미국,', '중국,', '한국', '출원', '가능성', '희박', '만약', '상황', '전방위', '전', '체계', '구축', '자율주행', '기술', '기초', '완성도', '말']

# %% [markdown]
# 주제와 연관된 단어들이 자주 출현한 것을 볼 수 있습니다.

# %%
# 명사만 추출된 리스트
word_list=temp

# 문서에 출현한 각 명사로부터 Series 객체를 생성 (index는 0부터 시작하는 정수값)
# 0 차량
# 1 고장
# 2 제동
# 3 차량
# 4 고장
# 5 ...
word_list=pd.Series([x for x in word_list if len(x)>1])

# pd.Series.value_counts: Returns a Series containing counts of unique values.
# The resulting object will be in descending order so that the first element is the most frequently-occurring element.  
word_list.value_counts().head(10), data_shuffled.iloc[0]['주제']
# Out:
# (차량       16
#  고장       10
#  관제시스템     6
#  자율주행      6
#  제동        6
#  시스템       6
#  주행        5
#  신호        4
#  장치        4
#  기술        4
#  dtype: int64, '모빌리티')

# %% [markdown]
# ***
#
# ##**< DBSCAN 예제 : 기사 분석하기 >**
# 기후변화, 유산균, 모빌리티에 관한 기사 제목과 기사 내용을 저장한 데이터에 대해 DBSCAN을 적용합니다.

# %%
# 기사 내용중 명사만을 추출하여 docs 리스트에 저장합니다. # 형태소 분석
docs = []
for i in data_shuffled['body']:
    docs.append(hannanum.nouns(i))

# 공백 문자를 넣어서 각 단어를 합칩니다.
for i in range(len(docs)):
    docs[i] = ' '.join(docs[i])

docs[0]
# Out:
# '[자료=현대자동차] 현대차그룹 오늘(26일) 특허 출원 자율주행 차량 브레이크 고장 대응 시스템 을 테크 사이트 공개 현대차그룹 해당 기술 완전 자율주행 모빌리티 전제 브레이크 장치 오류 발생 예기치 상황 차량 간 상호작용 피해 최소 대응 기술 설명 브레이크 고장 시스템 자율주행 차량 주행 도중 제동 필요 상황 전자 제어장치 제동 장치 작동 확인 반응 전자 제어장치 한번 보조 제동 장치 제동 가능 여부 판별 이때 보조 제동 장치 사용 불가능 판단 전자 제어장치 자율주행 관제시스템 제동 시스템 문제 신호 전달 정보 전달 관제시스템 고장 차량 가까이 주행 중 차량 구조 신호 신호 수 한 자율주행 차량 고장 차량 안전 정지 고장 차량 관제시스템 전달한 정보 토대 조향 시스템 제 구조 진행 상황 관제시스템 전달함 고장 차량 차선 주행 접근 관제시스템 고장 차량 무사 처리 주변 차량들 해당 차선 주행 지시 차선 이동한 차량 주행 속도 조향 시스템 조절 고장 차량 범퍼 접촉 차량 속도 줄 한 차량 제어 고장 차량 관제시스템 구조 완료 신호 후 구조 작업 무선 통신 주변 차량 상호작용 사고 완화 것 현대차그룹 브레이크 고장 대응 시스템 기술 특허 미국, 중국, 한국 출원 가능성 희박 만약 상황 전방위 전 체계 구축 자율주행 기술 기초 완성도 말'

# %% [markdown]
# 처음 한나눔 분석기를 이용해서 명사만 추출한 docs의 구조는 다음과 같은 이중 리스트로 구성되어 있습니다.
#
# - [[문장1], [문장2], ... , [문장70]]
#
# 두번째 for문을 이용하면 docs는 다음과 같이 변형되고
#
# - [문장1, 문장2, ... , 문장70]
#
# 각 리스트의 원소가 명사들 사이에 공백이 삽입된 텍스트로 바뀝니다.

# %%
# TF_IDF로 변환
# sklearn.feature_extraction.text.TfidfVectorizer :
# Converts a collection of raw documents to a matrix of TF-IDF features (document-term matrix)
# ngram_range(min_n, max_n): all values of n such that min_n <= n <= max_n will be used. 
# min_df : ignore terms that have a document frequency lower than the given threshold.
from sklearn.feature_extraction.text import TfidfVectorizer

# n(1 to 5)gram 을 사용하여 위 기사의 명사들을 tfidf vector로 변환
tfidf_vectorizer = TfidfVectorizer(min_df = 3, ngram_range=(1,5))
tfidf_vectorizer.fit(docs)
vector = tfidf_vectorizer.transform(docs).toarray()
print(vector.shape) # num_of_documents X vocab
# DTM (Document, Term Matrix)
# Out:
# (198, 3324)

# %% [markdown]
# sklearn.cluster.DBSCAN:
# eps : maximum distance between two samples (default 0.5)
# min_samples=5 : The number of samples (or total weight) in a neighborhood for a point to be considered as a core point (default 5)
# metric: The metric to use when calculating distance between instances in a feature array. (default 'euclidean')

# %%
# sklearn.cluster.DBSCAN: Performs DBSCAN clustering from vector array
# eps: maximum distance between two samples (default 0.5)
# min_samples: The number of samples in a neighborhood for a point to be considered as a core point (default 5) 
# metric: The metric to use when calculating distance between instances in a feature array. (default 'euclidean')
# 'cosine' distance == (1 - cosine similarity)
# ex) If 2 vectors are perfectly the same then the similarity is 1 (angle=0 hence 𝑐𝑜𝑠(𝜃)=1), and the distance is 0 (1–1=0).
from sklearn.cluster import DBSCAN
import numpy as np

vector = np.array(vector)
model = DBSCAN(eps=0.75, min_samples=3, metric = "cosine") 
result = model.fit_predict(vector) # Computes clusters from a data and predict labels.

# %%
# 클러스터 번호 -1에는 노이즈 데이터로 판별되어 클러스터링이 안된 문서들이 들어 있음
print('클러스터 번호: 클러스터에 속한 기사의 수')
result_dict = {str(i):list(result).count(i) for i in set(result)} # result의 각 클러스터에 속한 기사수를 카운트
result_dict
# Out:
# 클러스터 번호: 클러스터에 속한 기사의 수
# {'0': 11,
#  '1': 6,
#  '2': 6,
#  '3': 7,
#  '4': 19,
#  '5': 5,
#  '6': 4,
#  '7': 8,
#  '8': 6,
#  '9': 8,
#  '10': 6,
#  '11': 3,
#  '12': 4,
#  '13': 4,
#  '14': 3,
#  '15': 3,
#  '16': 6,
#  '17': 3,
#  '18': 3,
#  '19': 7,
#  '20': 3,
#  '21': 3,
#  '-1': 70}

# %% [markdown]
# DBSCAN 을 통해 클러스터링된 index 결과를 데이터 프레임에 추가합니다.
#
# 클러스터 -1에는 노이즈 데이터로 판별이 나서 클러스터링이 안된 문서가 들어 있습니다.

# %%
# 클러스터 번호를 column으로 추가
data_shuffled['result'] = result

# %%
sentences = []
max_cluster_num = 0
for cluster_num in set(result):
    sentence = ''

    # -1은 노이즈 판별이 났거나 클러스터링이 안된 경우
    if(cluster_num == -1): 
        continue
    else:
        max_cluster_num = cluster_num         # 생성된 클러스터의 갯수를 카운트
        temp_df = data_shuffled[data_shuffled['result'] == cluster_num] # cluster num 별로 조회

        print("cluster num : {}".format(cluster_num))
        # zip: 동일한 개수로 이루어진 자료형을 묶어 준다
        for data in zip(temp_df['title'], temp_df['body'], temp_df.iloc): 
            title, body, my_data = data
            print(my_data['주제'], ':', title) # 주제, 기사 제목을 출력
            sentence += body + ' '
        print()
    sentences.append(sentence)
# Out:
# cluster num : 0
# 모빌리티 : 세븐일레븐, 공유 킥보드 충전·대여 서비스 시작
# 모빌리티 : 유럽에서도 '카카오T'로 차량 호출…""22개국 확대""
# 기후위기 : [출발서해안시대] “민주당 최고위원에 호남 인사 전무…호남 소외 우려”
# 모빌리티 : [ET] ‘교통 취약계층’ 위한 카셰어링 시동…장애인·시니어 일자리까지 창출
# 모빌리티 : [여의도 사사건건] 양향자 “미중 패권 다툼은 반도체 전쟁, 위기 아닌 기회…우리 기술 패권으로 칩4 주도권 가질 수 있어”
# 모빌리티 : 아우디 AG, 상반기에 날았다...사상 최대 영업이익
# 모빌리티 : "버스 예매에 교통카드까지"…롯데카드, '모빌리티 서비스' 개시
# 모빌리티 : 현대차그룹 팹리스 스타트업 '보스반도체' 투자…미래차 반도체 시너지
# 기후위기 : [백브리핑] "칠곡서 책 쓰겠다" 이준석, 잠적 아닌 잠적
# 모빌리티 : [뉴스라이브] 미중 반도체 전쟁 '가속화'...한국에는 위기? 기회?
# 모빌리티 : 현대차, 상반기 첫 세계 3위…반도체 밀어주기 통했다
#
# cluster num : 1
# 모빌리티 : 티맵, KB로부터 2천억 투자 유치…이종호 "티맵의 철학은 상생"
# 모빌리티 : 대리운전업 갈등 2라운드…""대기업 꼼수로 시장 진출""
# 모빌리티 : 대리운전연합, 최태원 SK 회장에 손편지…"티맵 갈등 중재해달라"
# 모빌리티 : 대리운전연합, 내일부터 티맵 규탄대회…"사업확장제한 권고 어겨"
# 모빌리티 : 대리기사들 티맵에 뿔났다…대리운전 비용 높아질까?
# 모빌리티 : 티맵모빌리티, KB국민은행서 2천억원 유치
#
# cluster num : 2
# 유산균 : 야쿠르트도 10% 오른다‥hy, 내달 일부 제품 가격 인상
# 유산균 : 야쿠르트 라이트, 가격 10% 인상…쿠퍼스 2700원 된다
# 유산균 : hy, 야쿠르트 라이트 등 일부 제품 '가격 인상'
# 유산균 : "야쿠르트도 오른다"…hy, 내달 일부 제품 가격 인상
# 유산균 : 야쿠르트도 10% 오른다...hy, 9월부터 일부 제품 인상
# 유산균 : hy, 9월부터 일부 제품 가격 오른다…"제조원가 부담 심화"
#
# cluster num : 3
# 모빌리티 : 대리운전노조·카카오노조, “카카오모빌리티 매각 철회 환영”
# 모빌리티 : [속보] 카카오 ""카카오모빌리티 지분 매각 추진 중단""
# 모빌리티 : 대리운전노조, 카카오모빌리티 본사 앞 천막농성 돌입
# 모빌리티 : 카카오 “카카오모빌리티 지분 매각 추진 중단”
# 모빌리티 : "카카오모빌리티 매각 철회해야"…대리운전노조, 천막농성 돌입
# 모빌리티 : 카카오, 카카오모빌리티 지분 안 판다…진짜 속내는?
# 모빌리티 : 카카오 ""카카오모빌리티 지분 매각 추진 중단""
#
# cluster num : 4
# 유산균 : CJ웰케어, ‘BYO 유산균’ 누적 매출 2,500억원 돌파
# 유산균 : 국내 최초 다이어트 기능성 인정받은 유산균
# 유산균 : CJ웰케어, 바이오유산균 출시후 누적 매출 2500억 돌파
# 유산균 : 드시모네, 마켓컬리 전용 프리미엄 프로바이오틱스 선봬
# 유산균 : 종근당건강 락토핏, '2022 굿디자인 어워드' 우수디자인
# 유산균 : 락토핏 프리미엄 신제품 ‘락토핏 솔루션’ 새 모델 박서준 TVC 공개
# 유산균 : 동아제약, 프로바이오틱스 자체 브랜드 출시 '잰걸음'
# 유산균 : CJ웰케어, 'BYO 유산균' 누적 매출 2500억원 돌파
# 유산균 : GC녹십자웰빙, 광고 모델로 배우 신애라 발탁
# 유산균 : 일동바이오사이언스 ""프로바이오틱스 원료6종 캐나다 등록""
# 유산균 : 일동바이오사이언스, 프로바이오틱스 6종 캐나다 NHP 등록
# 유산균 : 일동바이오, 프로바이오틱스 6종 캐나다 NHP 등록…"미주 시장 개척에 속도"
# 유산균 : 바실러스 코아귤런스, 유산균 수 늘리는 데 사용한다?
# 유산균 : "장 때문이야~" 유산균, 식전이냐 식후냐... 섭취 타이밍은
# 유산균 : [심층K] 기능성원료은행 구축 추진…기능성 식품 산업 도약 발판
# 유산균 : hy, 대표 균주 ‘HY2782’ 미국 ‘자체 검증 GRAS’ 인증 취득
# 유산균 : 장내 미생물 균형 깨져도 기혈 막혀 살찐다""[비만돋보기]
# 유산균 : 링티, '임팩트 유산균 프리미엄' 약국으로 판매처 확대
# 유산균 : 종근당건강, 유산균 브랜드 '락토핏' 업그레이드 출시…9월 론칭
#
# cluster num : 5
# 기후위기 : 미-러 핵전쟁 시 50억명 이상 굶어 죽는다"" 美 연구팀 발표
# 기후위기 : 물에 잠긴 파키스탄 자파라바드
# 기후위기 : 파키스탄 “우기 홍수에 사망자 천명 넘어”…‘국가 비상사태’ 선포
# 기후위기 : 미-러 핵전쟁 나면 53억 명 굶어 죽는다""
# 기후위기 : '비야 그쳐라'..5월부터 폭우 파키스탄 사망자 1천 명↑
#
# cluster num : 6
# 모빌리티 : 내년 강원 국비 8조 7천억 원 반영…김진태 도정 ‘파란불’
# 모빌리티 : 내년 정부 예산안 3조 반영…역점사업 다수 포함
# 모빌리티 : 울산, 내년 정부 예산안 3조 반영…역점사업 다수 포함
# 모빌리티 : 강원도, 내년 국비 8조7천억여 원 확보…역대 최대
#
# cluster num : 7
# 모빌리티 : 공정위, KG모빌리티 쌍용차 주식 취득 승인…“경쟁제한 미미”
# 모빌리티 : 공정위, KG의 쌍용차 인수 승인…"경쟁 제한 우려 미미"
# 모빌리티 : 공정위, 'KG-쌍용차' 기업결합 승인…"경쟁제한 우려 없다"
# 모빌리티 : [김대호 박사의 오늘 기업·사람] TSMC·삼성전자·쌍용차·쏘카·마켓컬리·포스코홀딩스
# 모빌리티 : [기업] KG, 쌍용차 사명 'KG쌍용모빌리티'로 변경 추진
# 모빌리티 : 공정위, KG 쌍용차 인수 허가…채권단 동의가 관건
# 모빌리티 : 공정위, KG그룹의 쌍용차 인수 승인…"경쟁제한 우려 없다"
# 모빌리티 : 쌍용차, 회생계획 이행 위한 감자 · 유상증자 실시…10월 신주 상장 예정
#
# cluster num : 8
# 기후위기 : 울산과학대, 울산시 탄소중립지원센터에 최종 선정
# 기후위기 : 제주도의회, 기후위기 대응'탄소중립 논의 속도
# 기후위기 : [키워드이슈] 비거노믹스
# 기후위기 : [대담]이승아 기후위기대응탄소중립연구포럼 대표 의원
# 기후위기 : “이상 기후 잦아지는데”…울산시 대책은?
# 기후위기 : 충청북도, 탄소중립 녹색성장 기본 조례 입법예고
#
# cluster num : 9
# 유산균 : MBC ‘생방송 오늘아침’, 명절 선물 품목으로 키위 소개
# 유산균 : 롯데제과, 추석 선물세트 70여종 본격 판매
# 유산균 : '선택하라 rTG오메가3 1000' NS홈쇼핑 NS Shop+ 방송 론칭
# 유산균 : 롯데온, 22일부터 '추석 선물세트' 본판매…'온마음 한가위' 행사
# 유산균 : 동원F&B, 추석 맞이 건기식 선물세트 할인 행사 진행
# 유산균 : [추석 선물] 받으면 좋다, 필요한 건 더 좋다
# 유산균 : 정식품, 건강 간편 실속 담은 추석 선물세트 출시
# 유산균 : SM C&C, 워시밤 3종 한가위 에디션 출시
#
# cluster num : 10
# 기후위기 : 주미대사 “한미, 美인플레법 협의 합의”…法 개정까지 염두 총력
# 기후위기 : 인플레 감축법 서명 전 연설하는 바이든 미 대통령
# 기후위기 : '인플레 감축법' 서명하는 바이든 美 대통령
# 기후위기 : 바이든 인플레 감축법 서명…한국 전기차 보조금 제외
# 기후위기 : 이창양 산업부 장관, 주한 미국 대사에 “인플레 감축법 조속히 해결돼야”
# 기후위기 : 한국 전기차, 미국 보조금 혜택 대상서 제외
#
# cluster num : 11
# 기후위기 : 농업 컨트롤타워…농식품 기후변화센터 내년 착공
# 기후위기 : ‘상주 스마트팜 혁신밸리’ 미래 농업기술로 청년농 육성
# 기후위기 : 농식품 기후변화대응센터 예타 통과..사업 본궤도
#
# cluster num : 12
# 모빌리티 : [재택플러스] 심야택시 대란에 '웃돈' 논란‥해법은?
# 모빌리티 : 결국 택시요금도 오른다…'폭탄맛' 우버 엄포용이었나?
# 모빌리티 : [뉴스 열어보기] 새 검찰총장 이원석, 공정위원장엔 한기정 유력
# 모빌리티 : [뉴스 열어보기] ""급하면 3000원 더 내라"" 카카오가 장악한 택시
#
# cluster num : 13
# 유산균 : 추석 선물도 라방으로… CJ올리브영, '올영라이브' 진행
# 유산균 : CJ올리브영, 추석 특집 '올영라이브' 진행
# 유산균 : CJ올리브영, 추석 특집 라이브커머스 '올영라이브' 진행
# 유산균 : 추석 선물도 라방으로…CJ올리브영, 추석 특집 '올영라이브' 진행
#
# cluster num : 14
# 모빌리티 : 문체부 내년 예산 6.5% 감액…청와대 복합공간 조성에 217억 원
# 모빌리티 : [2023나라살림] 정부, 도로·철도·항공 SOC 예산 확 줄였다
# 모빌리티 : 국토부 내년 예산안 55.9조…주거복지 등 올해보다 4.2조↓
#
# cluster num : 15
# 모빌리티 : 현대모비스 생산 부문 분리 계열사 설립 추진…모듈·핵심부품 2개
# 모빌리티 : [김대호 박사의 오늘 기업·사람] 옥시덴탈·현대차·LG·삼성
# 모빌리티 : 현대모비스, '연구개발'과 '생산' 분리 재편...하청구조, 2개 생산전문 계열사로 흡수
#
# cluster num : 16
# 기후위기 : 타이완의 中 무인기 실탄사격에 “美, 중국정책 변화없어”
# 기후위기 : [특파원 리포트] ‘한중 수교 30주년’ 중국에서 ‘북핵’이 사라졌다…왜?
# 기후위기 : 바이든 대통령, 다음달 유엔총회 참석…한미정상 회동 가능성
# 기후위기 : “갈등이 있는 곳이면 어디라도”…방북 성사될까?
# 기후위기 : 미, 타이완의 중 무인기 실탄사격에 “중국정책 변화없어”
# 기후위기 : 도발 시동 거나…북한 선전매체, 한미연합훈련 비난｜아침& 월드
#
# cluster num : 17
# 유산균 : 홈앤쇼핑, PB브랜드 '이데이잇츠 콤부차' 출시
# 유산균 : 매일유업 콤부차, 구매 만족도 98% 달성…"깔끔한 발효 풍미"
# 유산균 : [중기소식]홈앤쇼핑, 자체 브랜드 '이데이잇츠' 출시 등
#
# cluster num : 18
# 기후위기 : 尹 정부, ‘원전 비중’ 대폭 확대…“발전 비중 역행” 반발
# 기후위기 : 한·미·일 등 13개국 “소형모듈원자로 활용 위해 협력”
# 기후위기 : [박상욱의 기후 1.5] EU·중에 뒤질세라…미, 재생에너지 투자에 박차
#
# cluster num : 19
# 기후위기 : [지수로 보는 날씨정보] 폭우에 예고 없이 ‘와르르’
# 기후위기 : [지수로 보는 날씨정보] 가을은 언제쯤?
# 기후위기 : 유럽 휩쓴 최악 폭염…2035년이면 일상 될 것""
# 기후위기 : 덥고 폭우 잦았던 여름, 가을 날씨 전망은?
# 기후위기 : [퍼센트] 20년 뒤 한국 여름 길이 증가율 35%…폭우가 남긴 숙제 ‘기후 위기’
# 기후위기 : [박상욱의 기후 1.5] 해마다 깨지는 '역대급 기록'…기후위기 시대 인프라 설계 기준은?
# 기후위기 : 가을은 언제쯤?…기후학적으로 9월 하순은 돼야
#
# cluster num : 20
# 유산균 : 케어비, '이유식 도락기행' 프로모션 진행
# 유산균 : 남양유업, '우리아이 영양 맞춤 이유식' 강의 진행
# 유산균 : 남양유업 배달 이유식 '케어비', '이유식도락 기행' 프로모션 진행
#
# cluster num : 21
# 기후위기 : 핵오염수 방류 저지 1인시위...道 대책 마련 들어가
# 기후위기 : [자막뉴스] ""이번엔 아프지마"" 바다로 돌아간 멸종위기 바다거북
# 기후위기 : 멸종위기 '바다거북' 고향 바다로

# %%
#클러스터 1번에 속한 데이터 확인
data_cluster1 = data_shuffled[data_shuffled.result==1]
data_cluster1
len(data_cluster1)
# Out:
# 6

# %%
# num_to_display: 각 클러스터당 출력할 최대 문서 개수
num_to_display = 5
# max_cluster_num: 생성된 클러스터 갯수
print(max_cluster_num + 1)
# Out:
# 22

# %%
# 각 클러스터 마다 데이터 출력해주기
for i in range(max_cluster_num+1):
  data_cluster = data_shuffled[data_shuffled.result==i]
  data_num = len(data_cluster)

  if len(data_cluster) > num_to_display:
    data_cluster = data_cluster[0:num_to_display]

  print('----- 클러스터 %i -----' %i)
  print('총 데이터 개수: %i' % data_num)
  print(data_cluster)
  print()
# Out:
# ----- 클러스터 0 -----
# 총 데이터 개수: 11
#                    date                                              title  \
# 3   2022-08-22 16:05:00                         세븐일레븐, 공유 킥보드 충전·대여 서비스 시작
# 46  2022-08-31 12:26:00                    유럽에서도 '카카오T'로 차량 호출…""22개국 확대""
# 54  2022-08-29 10:23:00            [출발서해안시대] “민주당 최고위원에 호남 인사 전무…호남 소외 우려”
# 78  2022-08-25 18:11:00         [ET] ‘교통 취약계층’ 위한 카셰어링 시동…장애인·시니어 일자리까지 창출
# 94  2022-08-24 16:13:00  [여의도 사사건건] 양향자 “미중 패권 다툼은 반도체 전쟁, 위기 아닌 기회…우리 ...
#
#                                                  body channel    주제  result
# 3   세븐일레븐 공유킥보드 충전 모습. /세븐일레븐 제공 편의점 세븐일레븐이 모빌리티 서...    news  모빌리티       0
# 46  카카오모빌리티가 다음 달부터 유럽에서도 카카오T 애플리케이션으로 현지 차량 호출 서...    news  모빌리티       0
# 54  [KBS 목포] ■ 인터뷰 자료의 저작권은 KBS에 있습니다. 인용보도 시 출처를 ...    news  기후위기       0
# 78  ■ 프로그램명 : 통합뉴스룸ET ■ 코너명 : 호모 이코노미쿠스 ■ 방송시간 : 8...    news  모빌리티       0
# 94  양향자 (국민의힘 반도체산업특별위원회 위원장) -반도체는 4차 산업의 기본...외교...    news  모빌리티       0
#
# ----- 클러스터 1 -----
# 총 데이터 개수: 6
#                     date                                 title  \
# 5    2022-08-22 11:48:00  티맵, KB로부터 2천억 투자 유치…이종호 "티맵의 철학은 상생"
# 114  2022-08-23 07:51:00       대리운전업 갈등 2라운드…""대기업 꼼수로 시장 진출""
# 119  2022-08-31 11:39:00  대리운전연합, 최태원 SK 회장에 손편지…"티맵 갈등 중재해달라"
# 171  2022-08-22 06:54:00   대리운전연합, 내일부터 티맵 규탄대회…"사업확장제한 권고 어겨"
# 184  2022-08-24 06:17:00           대리기사들 티맵에 뿔났다…대리운전 비용 높아질까?
#
#                                                   body channel    주제  result
# 5    [사진=티맵모빌리티] SK스퀘어의 자회사인 티맵모빌리티가 KB국민은행에서 2천억 원...    news  모빌리티       1
# 114  【 앵커멘트 】 대리운전업을 둘러싼 대기업과 중소기업 갈등이 2라운드에 접어들고 있...    news  모빌리티       1
# 119  대리운전업 분야에 대한 대기업의 사업확장이 제한됐음에도 SK스퀘어의 자회사인 티맵모...    news  모빌리티       1
# 171  티맵모빌리티 "근거없는 주장" 대리운전업계는 대리운전업 분야에 대한 대기업의 사업확...    news  모빌리티       1
# 184  [앵커] 지난 6월 카카오모빌리티 매각 추진 논란에 이어 티맵 모빌리티의 사업 확장...    news  모빌리티       1
#
# ----- 클러스터 2 -----
# 총 데이터 개수: 6
#                     date                              title  \
# 6    2022-08-18 11:23:00   야쿠르트도 10% 오른다‥hy, 내달 일부 제품 가격 인상
# 89   2022-08-18 10:45:00   야쿠르트 라이트, 가격 10% 인상…쿠퍼스 2700원 된다
# 90   2022-08-18 11:09:00       hy, 야쿠르트 라이트 등 일부 제품 '가격 인상'
# 91   2022-08-18 10:32:00     "야쿠르트도 오른다"…hy, 내달 일부 제품 가격 인상
# 120  2022-08-18 15:10:00  야쿠르트도 10% 오른다...hy, 9월부터 일부 제품 인상
#
#                                                   body channel   주제  result
# 6    hy 제공 옛 한국야쿠르트인 hy는 일부 제품에 대해 9월 1일 가격을 인상한다고 ...    news  유산균       2
# 89   hy(옛 한국야쿠르트)는 일부 제품에 대해 다음달 1일부터 가격을 인상한다고 오늘(...    news  유산균       2
# 90   [서울=뉴시스]김혜경 기자 = hy가 일부 제품에 대해 9월1일부터 가격을 인상한다...    news  유산균       2
# 91   ⓒhy [데일리안 = 임유정 기자] hy가 일부 제품에 대해 9월 1일부로 가격을 ...    news  유산균       2
# 120  [사진제공: hy] hy(옛 한국야쿠르트)가 일부 제품에 대해 9월 1일부로 가격을...    news  유산균       2
#
# ----- 클러스터 3 -----
# 총 데이터 개수: 7
#                     date                              title  \
# 7    2022-08-18 15:08:00   대리운전노조·카카오노조, “카카오모빌리티 매각 철회 환영”
# 38   2022-08-18 10:15:00   [속보] 카카오 ""카카오모빌리티 지분 매각 추진 중단""
# 104  2022-08-17 17:27:00       대리운전노조, 카카오모빌리티 본사 앞 천막농성 돌입
# 134  2022-08-18 10:17:00          카카오 “카카오모빌리티 지분 매각 추진 중단”
# 149  2022-08-17 17:58:00  "카카오모빌리티 매각 철회해야"…대리운전노조, 천막농성 돌입
#
#                                                   body channel    주제  result
# 7    전국대리운전노동조합과 카카오 노동조합은 카카오가 카카오모빌리티 지분 매각 추진을 중...    news  모빌리티       3
# 38                    [속보] 카카오 ""카카오모빌리티 지분 매각 추진 중단""    news  모빌리티       3
# 104  자료 제공: 연합뉴스 전국대리운전노동조합과, 카카오노동조합인 '크루 유니언'은 오늘...    news  모빌리티       3
# 134  카카오가 카카오모빌리티의 지분 일부 매각 추진을 중단한다고 오늘(18일) 공시했습니...    news  모빌리티       3
# 149  전국대리운전노동조합이 오늘(17일)부터 카카오·카카오모빌리티 본사 앞에 천막을 설치...    news  모빌리티       3
#
# ----- 클러스터 4 -----
# 총 데이터 개수: 19
#                    date                              title  \
# 8   2022-08-31 07:38:00  CJ웰케어, ‘BYO 유산균’ 누적 매출 2,500억원 돌파
# 14  2022-08-31 02:34:00            국내 최초 다이어트 기능성 인정받은 유산균
# 24  2022-08-31 08:12:00   CJ웰케어, 바이오유산균 출시후 누적 매출 2500억 돌파
# 29  2022-08-24 11:02:00      드시모네, 마켓컬리 전용 프리미엄 프로바이오틱스 선봬
# 40  2022-08-29 11:23:00   종근당건강 락토핏, '2022 굿디자인 어워드' 우수디자인
#
#                                                  body channel   주제  result
# 8   CJ웰케어는 ‘BYO 유산균(바이오)’이 출시 후 누적 매출 2,500억원을 돌파했...    news  유산균       4
# 14  [2022 국민공감 캠페인] 소비자신뢰브랜드(건강기능식품) / 3년 연속 ㈜에이스바...    news  유산균       4
# 24  [서울=뉴시스] 김동현 기자 = CJ웰케어는 '바이오 유산균'이 출시 후 누적 매출...    news  유산균       4
# 29  9월5일까지 2주간 론칭 기념 최대 40% 할인 프로모션 ⓒ헥토헬스케어 [데일리안 ...    news  유산균       4
# 40  종근당건강 제공 (서울=뉴스1) 임해중 기자 = 종근당건강의 프로바이오틱스 브랜드 ...    news  유산균       4
#
# ----- 클러스터 5 -----
# 총 데이터 개수: 5
#                     date                                 title  \
# 1    2022-08-16 19:50:00   미-러 핵전쟁 시 50억명 이상 굶어 죽는다"" 美 연구팀 발표
# 9    2022-08-30 16:04:00                      물에 잠긴 파키스탄 자파라바드
# 26   2022-08-29 06:20:00  파키스탄 “우기 홍수에 사망자 천명 넘어”…‘국가 비상사태’ 선포
# 56   2022-08-17 07:21:00             미-러 핵전쟁 나면 53억 명 굶어 죽는다""
# 117  2022-08-29 10:45:00      '비야 그쳐라'..5월부터 폭우 파키스탄 사망자 1천 명↑
#
#                                                   body channel    주제  result
# 1    미국과 러시아가 핵전쟁을 할 경우 전 세계 50억명 이상의 사람이 굶주림으로 숨질 ...    news  기후위기       5
# 9    (자파라바드 AP=연합뉴스) 29일(현지시간) 파키스탄 남서부 발루치스탄주 자파라바...    news  기후위기       5
# 26   파키스탄에서 올해 몬순 우기 홍수로 인한 사망자가 천명을 넘었습니다. 파키스탄 국가...    news  기후위기       5
# 56   ▲러시아의 대륙간탄도미사일(ICBM) 시험 발사 사진: 연합뉴스 미국과 러시아가 핵...    news  기후위기       5
# 117  ▲ 파키스탄 우기 홍수 사진 : 연합뉴스 파키스탄에서 5월 이후 계속된 폭우로 사망...    news  기후위기       5
#
# ----- 클러스터 6 -----
# 총 데이터 개수: 4
#                     date                              title  \
# 11   2022-08-30 23:38:00  내년 강원 국비 8조 7천억 원 반영…김진태 도정 ‘파란불’
# 12   2022-08-30 23:19:00         내년 정부 예산안 3조 반영…역점사업 다수 포함
# 79   2022-08-31 07:35:00     울산, 내년 정부 예산안 3조 반영…역점사업 다수 포함
# 195  2022-08-31 07:36:00       강원도, 내년 국비 8조7천억여 원 확보…역대 최대
#
#                                                   body channel    주제  result
# 11   [KBS 강릉] [앵커] 정부가 오늘(30일), 국무회의를 통해 내년 정부 예산안을...    news  모빌리티       6
# 12   [KBS 울산] [앵커] 639조 원 규모의 내년도 정부 예산안이 국무회의를 통과한...    news  모빌리티       6
# 79   [KBS 울산][앵커] 639조 원 규모의 내년도 정부 예산안이 국무회의를 통과한 ...    news  모빌리티       6
# 195  [KBS 춘천]강원도가 내년에 역대 최대 규모인 8조 7천억여 원의 국비를 확보했습...    news  모빌리티       6
#
# ----- 클러스터 7 -----
# 총 데이터 개수: 8
#                     date                                            title  \
# 13   2022-08-24 10:03:00               공정위, KG모빌리티 쌍용차 주식 취득 승인…“경쟁제한 미미”
# 23   2022-08-24 10:41:00                 공정위, KG의 쌍용차 인수 승인…"경쟁 제한 우려 미미"
# 44   2022-08-24 13:28:00               공정위, 'KG-쌍용차' 기업결합 승인…"경쟁제한 우려 없다"
# 108  2022-08-23 08:21:00  [김대호 박사의 오늘 기업·사람] TSMC·삼성전자·쌍용차·쏘카·마켓컬리·포스코홀딩스
# 143  2022-08-29 17:36:00                [기업] KG, 쌍용차 사명 'KG쌍용모빌리티'로 변경 추진
#
#                                                   body channel    주제  result
# 13   쌍용차 최종인수예정자로 선정된 KG그룹의 쌍용차 주식 취득을 공정거래위원회가 승인했...    news  모빌리티       7
# 23   공정거래위원회가 KG그룹이 쌍용자동차를 인수하는 기업결합을 승인했다고 밝혔습니다. ...    news  모빌리티       7
# 44   공정거래위원회가 KG모빌리티와 쌍용자동차의 기업결합 건을 승인했다. 공정위는 24일...    news  모빌리티       7
# 108  TSMC·삼성전자·쌍용차·쏘카·마켓컬리·포스코홀딩스 ◇ 운명의 관계인집회 쌍용차 쌍...    news  모빌리티       7
# 143  KG그룹이 쌍용차의 사명을 'KG쌍용모빌리티'로 변경합니다. KG그룹은 다음 달 1...    news  모빌리티       7
#
# ----- 클러스터 8 -----
# 총 데이터 개수: 6
#                     date                         title  \
# 15   2022-08-31 07:45:00    울산과학대, 울산시 탄소중립지원센터에 최종 선정
# 45   2022-08-22 14:13:00     제주도의회, 기후위기 대응'탄소중립 논의 속도
# 82   2022-08-30 19:48:00                 [키워드이슈] 비거노믹스
# 155  2022-08-22 21:11:00  [대담]이승아 기후위기대응탄소중립연구포럼 대표 의원
# 185  2022-08-26 07:38:00        “이상 기후 잦아지는데”…울산시 대책은?
#
#                                                   body channel    주제  result
# 15   [KBS 울산]울산과학대학교가 울산시 탄소중립 지원센터 지정 공모에 최종 선정됐습니...    news  기후위기       8
# 45   의원연구단체 '기후위기 대응 탄소중립 연구포럼' 창립 오늘(22일) 진행된 제주도의...    news  기후위기       8
# 82   [KBS 부산]최근 기후변화로 인해 폭염과 폭우, 가뭄 등 전세계가 몸살을 앓고 있...    news  기후위기       8
# 155  (앵커) 기후 위기로 인한 생활상의 변화는 갈수록 빨라지고 있습니다. 제주자치도가 ...    news  기후위기       8
# 185  [KBS 울산] [앵커] 최근 집중호우나 폭염 같은 이상 기후 현상이 잦은데요 이 ...    news  기후위기       8
#
# ----- 클러스터 9 -----
# 총 데이터 개수: 8
#                     date                                     title  \
# 4    2022-08-30 16:35:00          MBC ‘생방송 오늘아침’, 명절 선물 품목으로 키위 소개
# 17   2022-08-24 09:51:00                  롯데제과, 추석 선물세트 70여종 본격 판매
# 33   2022-08-22 10:25:00  '선택하라 rTG오메가3 1000' NS홈쇼핑 NS Shop+ 방송 론칭
# 58   2022-08-21 06:00:00     롯데온, 22일부터 '추석 선물세트' 본판매…'온마음 한가위' 행사
# 145  2022-08-31 08:13:00            동원F&B, 추석 맞이 건기식 선물세트 할인 행사 진행
#
#                                                   body channel   주제  result
# 4    ■ 장 건강 개선하는 그린키위 · 비타민C 풍부한 썬골드키위 ■ 식이섬유 많은 ‘그...    news  유산균       9
# 17   친환경 선물세트로 플라스틱 사용량 100톤 줄여 쇼핑백 부직포 소재도 100% 종이...    news  유산균       9
# 33   자연애에프앤비 제공 (서울=뉴스1) 임해중 기자 = 자연애에프앤비는 식약처 인정 건...    news  유산균       9
# 58   '물가 안정' 주제로 행사기간 최대 20% 할인 '온마음 한가위' 프로모션.(롯데온...    news  유산균       9
# 145  [서울=뉴시스] 김동현 기자 = 동원F&B는 추석을 맞아 건강기능식품 선물세트 할인...    news  유산균       9
#
# ----- 클러스터 10 -----
# 총 데이터 개수: 6
#                     date                                     title  \
# 18   2022-08-30 05:40:00       주미대사 “한미, 美인플레법 협의 합의”…法 개정까지 염두 총력
# 34   2022-08-17 08:31:00               인플레 감축법 서명 전 연설하는 바이든 미 대통령
# 57   2022-08-17 08:17:00                  '인플레 감축법' 서명하는 바이든 美 대통령
# 103  2022-08-17 11:23:00              바이든 인플레 감축법 서명…한국 전기차 보조금 제외
# 153  2022-08-31 17:33:00  이창양 산업부 장관, 주한 미국 대사에 “인플레 감축법 조속히 해결돼야”
#
#                                                   body channel    주제  result
# 18   조태용 주미한국대사는 미국의 인플레이션 감축법 제정에 따른 한국산 전기차 보조금 지...    news  기후위기      10
# 34   (워싱턴DC EPA=연합뉴스) 조 바이든 미국 대통령이 16일(현지시간) 미국 워싱...    news  기후위기      10
# 57   (워싱턴DC AP=연합뉴스) 조 바이든 미국 대통령이 16일(현지시간) 워싱턴DC ...    news  기후위기      10
# 103  〈사진=AP 연합뉴스〉 조 바이든 미국 대통령이 백악관에서 기후변화 대응과 의료보장...    news  기후위기      10
# 153  이창양 산업통상자원부 장관은 오늘(31일) 정부서울청사에서 필립 골드버그 주한 미국...    news  기후위기      10
#
# ----- 클러스터 11 -----
# 총 데이터 개수: 3
#                     date                           title  \
# 30   2022-08-25 21:57:00       농업 컨트롤타워…농식품 기후변화센터 내년 착공
# 32   2022-08-25 21:53:00  ‘상주 스마트팜 혁신밸리’ 미래 농업기술로 청년농 육성
# 133  2022-08-25 21:26:00      농식품 기후변화대응센터 예타 통과..사업 본궤도
#
#                                                   body channel    주제  result
# 30   [KBS 광주] [앵커] 농업 기후변화 대응을 총괄하는 농식품 기후변화대응센터가 정...    news  기후위기      11
# 32   [KBS 대구] [앵커] 민선 8기 지역 자치단체들의 현안을 살펴보는 연속 기획 순...    news  기후위기      11
# 133  【 앵커멘트 】 전남도가 지난해 유치한 '농식품 기후변화대응센터'가 정부의 예비타당...    news  기후위기      11
#
# ----- 클러스터 12 -----
# 총 데이터 개수: 4
#                    date                                     title  \
# 31  2022-08-25 07:37:00             [재택플러스] 심야택시 대란에 '웃돈' 논란‥해법은?
# 62  2022-08-26 18:09:00             결국 택시요금도 오른다…'폭탄맛' 우버 엄포용이었나?
# 68  2022-08-18 06:36:00       [뉴스 열어보기] 새 검찰총장 이원석, 공정위원장엔 한기정 유력
# 71  2022-08-23 06:34:00  [뉴스 열어보기] ""급하면 3000원 더 내라"" 카카오가 장악한 택시
#
#                                                  body channel    주제  result
# 31  [뉴스투데이] ◀ 앵커 ▶ 요즘 저녁 시간에 택시 잡기가 힘든 이른바 '심야 택시 ...    news  모빌리티      12
# 62  [앵커]  심야 시간 택시 대란이 장기화되자 서울시가 결국 요금 인상을 추진하기로 ...    news  모빌리티      12
# 68  [뉴스투데이] ◀ 앵커 ▶ ‘뉴스 열어보기’ 시작합니다. ◀ 앵커 ▶ 오늘은 차기 ...    news  모빌리티      12
# 71  [뉴스투데이] ◀ 앵커 ▶ ‘뉴스 열어보기’ 시작합니다. ◀ 앵커 ▶ 코로나 팬데믹...    news  모빌리티      12
#
# ----- 클러스터 13 -----
# 총 데이터 개수: 4
#                     date                                 title  \
# 37   2022-08-24 10:11:00       추석 선물도 라방으로… CJ올리브영, '올영라이브' 진행
# 115  2022-08-24 11:22:00              CJ올리브영, 추석 특집 '올영라이브' 진행
# 122  2022-08-24 09:45:00       CJ올리브영, 추석 특집 라이브커머스 '올영라이브' 진행
# 136  2022-08-24 13:20:00  추석 선물도 라방으로…CJ올리브영, 추석 특집 '올영라이브' 진행
#
#                                                   body channel   주제  result
# 37   고물가·비대면 선물 수요 반영 추석특집 '올영라이브' 대표 이미지(올리브영 제공)....    news  유산균      13
# 115  [서울=뉴시스]이지영 기자 = CJ올리브영은 추석 특집 라이브커머스 '올영라이브'를...    news  유산균      13
# 122  24일·31일 2회 편성...화장품·건기식 등 선물세트 판매 CJ올리브영(이하 올리...    news  유산균      13
# 136  24일, 31일 총 2회 걸쳐 추석 선물 제안하는 라이브커머스 '올영라이브' 진행 ...    news  유산균      13
#
# ----- 클러스터 14 -----
# 총 데이터 개수: 3
#                     date                                  title  \
# 43   2022-08-30 10:14:00  문체부 내년 예산 6.5% 감액…청와대 복합공간 조성에 217억 원
# 174  2022-08-30 11:18:00   [2023나라살림] 정부, 도로·철도·항공 SOC 예산 확 줄였다
# 178  2022-08-30 10:01:00     국토부 내년 예산안 55.9조…주거복지 등 올해보다 4.2조↓
#
#                                                   body channel    주제  result
# 43   정부가 내년 문화예술·체육·관광·문화재 분야 예산으로 올해보다 6.5% 감액한 8조...    news  모빌리티      14
# 174  [KTX(SBS Biz 자료사진)] 국토교통부가 내년 예산안을 55조 8885억 원...    news  모빌리티      14
# 178  국토교통부는 2023년도 예산안을 55.9조원으로 편성해 올해 예산 대비 4.2조원...    news  모빌리티      14
#
# ----- 클러스터 15 -----
# 총 데이터 개수: 3
#                     date                                              title  \
# 49   2022-08-18 16:45:00                현대모비스 생산 부문 분리 계열사 설립 추진…모듈·핵심부품 2개
# 95   2022-08-22 08:23:00                  [김대호 박사의 오늘 기업·사람] 옥시덴탈·현대차·LG·삼성
# 128  2022-08-19 08:41:00  현대모비스, '연구개발'과 '생산' 분리 재편...하청구조, 2개 생산전문 계열사로 흡수
#
#                                                   body channel    주제  result
# 49   현대모비스가 미래 모빌리티 환경에 대응하기 위해 생산 부문을 분리해 별도의 자회사를...    news  모빌리티      15
# 95   ■ 경제와이드 모닝벨 오늘 기업 오늘 사람 - 김대호 글로벌이코노믹연구소장 ◇ 워런...    news  모빌리티      15
# 128  [OSEN=강희수 기자] 현대모비스가 한꺼번에 2개의 계열사를 설립한다. 11월 출...    news  모빌리티      15
#
# ----- 클러스터 16 -----
# 총 데이터 개수: 6
#                     date                                      title  \
# 51   2022-08-31 04:37:00            타이완의 中 무인기 실탄사격에 “美, 중국정책 변화없어”
# 76   2022-08-25 14:32:00  [특파원 리포트] ‘한중 수교 30주년’ 중국에서 ‘북핵’이 사라졌다…왜?
# 116  2022-08-27 01:42:00           바이든 대통령, 다음달 유엔총회 참석…한미정상 회동 가능성
# 141  2022-08-25 21:10:00                 “갈등이 있는 곳이면 어디라도”…방북 성사될까?
# 147  2022-08-31 06:43:00            미, 타이완의 중 무인기 실탄사격에 “중국정책 변화없어”
#
#                                                   body channel    주제  result
# 51   백악관이 타이완의 중국 무인기 실탄 사격과 관련해 "하나의 중국 정책에는 변화가 없...    news  기후위기      16
# 76   24일 베이징에서 열린 한중 수교 30주년 기념 행사에서 정재호 주중한국대사가 윤석...    news  기후위기      16
# 116  조 바이든 미국 대통령이 제77차 유엔 총회 참석차 다음달 18일부터 사흘간 뉴욕을...    news  기후위기      16
# 141  [앵커] "고통 앞에서 중립을 지킬 수는 없다" 2014년 한국에서 돌아가는 길, ...    news  기후위기      16
# 147  미국 백악관이 타이완의 중국 무인기 실탄 사격과 관련해 "하나의 중국 정책에는 변화...    news  기후위기      16
#
# ----- 클러스터 17 -----
# 총 데이터 개수: 3
#                     date                                title  \
# 59   2022-08-17 09:09:00           홈앤쇼핑, PB브랜드 '이데이잇츠 콤부차' 출시
# 63   2022-08-26 09:59:00  매일유업 콤부차, 구매 만족도 98% 달성…"깔끔한 발효 풍미"
# 138  2022-08-17 09:06:00      [중기소식]홈앤쇼핑, 자체 브랜드 '이데이잇츠' 출시 등
#
#                                                   body channel   주제  result
# 59   '맛있는 콤부차 레몬' 선봬…건기식도 순차 출시 이데이잇츠(홈앤쇼핑 제공) (서울=...    news  유산균      17
# 63   '더그레잇티 콤부차 오리지널·베리리치', 카카오 선판매 '구아검가수분해물' 함유해 ...    news  유산균      17
# 138  [서울=뉴시스] 홈앤쇼핑 '이데이잇츠' 콤부차. (사진=홈앤쇼핑 제공) 2022.0...    news  유산균      17
#
# ----- 클러스터 18 -----
# 총 데이터 개수: 3
#                    date                                     title  \
# 36  2022-08-31 06:00:00         尹 정부, ‘원전 비중’ 대폭 확대…“발전 비중 역행” 반발
# 60  2022-08-26 06:28:00           한·미·일 등 13개국 “소형모듈원자로 활용 위해 협력”
# 70  2022-08-22 08:03:00  [박상욱의 기후 1.5] EU·중에 뒤질세라…미, 재생에너지 투자에 박차
#
#                                                  body channel    주제  result
# 36  윤석열 정부의 '반 탈원전'이 본격화되고 있습니다. 2030년까지 원자력 발전 비중...    news  기후위기      18
# 60  한국과 미국, 일본 등 13개국이 현지 시간 25일 미국 주도의 '소형모듈원자로 기...    news  기후위기      18
# 70  '먼 미래'에서 '내 일'로 찾아온 기후변화 (145) 그래픽으로 보는 글로벌 재생...    news  기후위기      18
#
# ----- 클러스터 19 -----
# 총 데이터 개수: 7
#                     date                                           title  \
# 27   2022-08-22 08:52:00                   [지수로 보는 날씨정보] 폭우에 예고 없이 ‘와르르’
# 77   2022-08-23 07:51:00                          [지수로 보는 날씨정보] 가을은 언제쯤?
# 99   2022-08-26 15:50:00                    유럽 휩쓴 최악 폭염…2035년이면 일상 될 것""
# 109  2022-08-24 21:00:00                        덥고 폭우 잦았던 여름, 가을 날씨 전망은?
# 135  2022-08-21 18:22:00  [퍼센트] 20년 뒤 한국 여름 길이 증가율 35%…폭우가 남긴 숙제 ‘기후 위기’
#
#                                                   body channel    주제  result
# 27   오늘(22일) 충북 세종지역은 대체로 맑은 가운데 한낮 32도 안팎의 무더위가 기승...    news  기후위기      19
# 77   여름 더위가 물러간다는 절기 '처서'인 오늘(23일) 충북 세종지역은 대체로 흐리고...    news  기후위기      19
# 99   〈사진=EPA 연합뉴스〉 최근 몇 달 동안 유럽을 달군 폭염이 2035년이면 일상이...    news  기후위기      19
# 109  <앵커> 절기는 못속인다고, 처서를 지나며 찜통더위는 한풀 꺾였습니다. 올 여름 충...    news  기후위기      19
# 135  [앵커] 115년 만에 내린 이번 폭우로 다시 한 번 기후 위기 에 대해 생각해보게...    news  기후위기      19
#
# ----- 클러스터 20 -----
# 총 데이터 개수: 3
#                     date                                  title  \
# 102  2022-08-24 08:24:00                케어비, '이유식 도락기행' 프로모션 진행
# 125  2022-08-30 08:37:00           남양유업, '우리아이 영양 맞춤 이유식' 강의 진행
# 129  2022-08-24 08:41:00  남양유업 배달 이유식 '케어비', '이유식도락 기행' 프로모션 진행
#
#                                                   body channel   주제  result
# 102  [서울=뉴시스] 김동현 기자 = 남양유업의 이유식 브랜드 케어비는 '한여름에도 우리...    news  유산균      20
# 125  [서울=뉴시스] 김동현 기자 = 남양유업이 다음달 2일 유튜브 채널을 통해 '우리아...    news  유산균      20
# 129  (남양유업 제공) (서울=뉴스1) 이상학 기자 = 남양유업의 영양 맞춤 배달 이유식...    news  유산균      20
#
# ----- 클러스터 21 -----
# 총 데이터 개수: 3
#                     date                                  title  \
# 106  2022-08-22 21:15:00          핵오염수 방류 저지 1인시위...道 대책 마련 들어가
# 157  2022-08-25 18:06:00  [자막뉴스] ""이번엔 아프지마"" 바다로 돌아간 멸종위기 바다거북
# 160  2022-08-25 20:59:00                     멸종위기 '바다거북' 고향 바다로
#
#                                                   body channel    주제  result
# 106  일본 정부의 후쿠시마 원전 오염수 방류를 저지하기 위한 서명 운동이 시작됐습니다. ...    news  기후위기      21
# 157  새끼 거북들이 모래 위에서 한 발 한 발 내딛기 시작합니다. 처음 만나는 바다가 두...    news  기후위기      21
# 160  (앵커) 구조된 뒤 치료를 마쳤거나 인공부화된 바다거북들이 오늘 고향인 바다로 돌아...    news  기후위기      21
