# %% [markdown]
# #### 머신러닝 코드 구조 <br>
#
# ![이미지](https://github.com/DA4BAM/dataset/blob/master/new_code.png?raw=true "code step1")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
stock = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/SK.csv') 
stock.drop('AdjClose', axis=1, inplace=True)

exch_rate = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/USD_KRW.csv')
exch_rate.drop(['open', 'high', 'low'], axis=1, inplace=True)
exch_rate.rename(columns={'date':'Date', 'close':'exch_Close', 'diff':'exch_Diff'},inplace=True)

# %%
exch_rate.head()
# Out:
#          Date  exch_Close  exch_Diff
# 0  2019-12-31      1155.1    -0.0025
# 1  2019-12-30      1158.0    -0.0015
# 2  2019-12-27      1159.7    -0.0023
# 3  2019-12-26      1162.3     0.0013
# 4  2019-12-25      1160.8    -0.0024

# %%
# 하나의 데이터로 결합
# how, on : stock의 Date를 기준으로
data = pd.merge(stock, exch_rate, how='left', on='Date')

data.head()
# Out:
#          Date      Open      High       Low     Close    Volume  exch_Close  \
# 0  2016-01-04  243000.0  245000.0  234500.0  234500.0  173905.0      1190.4
# 1  2016-01-05  236000.0  244000.0  234000.0  241000.0  182985.0      1190.8
# 2  2016-01-06  241000.0  243000.0  237500.0  239000.0  108574.0      1200.5
# 3  2016-01-07  237000.0  243000.0  236000.0  240500.0  113376.0      1197.3
# 4  2016-01-08  240500.0  242500.0  235000.0  241500.0   81557.0      1207.9
#
#    exch_Diff
# 0     0.0127
# 1     0.0004
# 2     0.0082
# 3    -0.0027
# 4     0.0089

# %% [markdown]
# ## 1. 데이터 이해

# %% [markdown]
# ### 1) 둘러보기

# %%
data.head()
# Out:
#          Date      Open      High       Low     Close    Volume  exch_Close  \
# 0  2016-01-04  243000.0  245000.0  234500.0  234500.0  173905.0      1190.4
# 1  2016-01-05  236000.0  244000.0  234000.0  241000.0  182985.0      1190.8
# 2  2016-01-06  241000.0  243000.0  237500.0  239000.0  108574.0      1200.5
# 3  2016-01-07  237000.0  243000.0  236000.0  240500.0  113376.0      1197.3
# 4  2016-01-08  240500.0  242500.0  235000.0  241500.0   81557.0      1207.9
#
#    exch_Diff
# 0     0.0127
# 1     0.0004
# 2     0.0082
# 3    -0.0027
# 4     0.0089

# %%
# Date를 Datetime 자료형으로 바꿔주기
data.dtypes
# Out:
# Date           object
# Open          float64
# High          float64
# Low           float64
# Close         float64
# Volume        float64
# exch_Close    float64
# exch_Diff     float64
# dtype: object

# %%
data.shape
# Out:
# (977, 8)

# %% [markdown]
# ### 2) 기초통계량

# %%
data.describe()
# Out:
#                 Open           High            Low          Close  \
# count     972.000000     972.000000     972.000000     972.000000
# mean   252080.761317  255116.255144  248993.312757  252241.769547
# std     29305.098277   29550.396185   28885.988224   29268.540457
# min    193000.000000  194500.000000  189000.000000  192500.000000
# 25%    227500.000000  230375.000000  224875.000000  227875.000000
# 50%    256250.000000  259500.000000  253500.000000  256750.000000
# 75%    274500.000000  277125.000000  270625.000000  274000.000000
# max    331000.000000  331000.000000  321500.000000  328500.000000
#
#              Volume   exch_Close   exch_Diff
# count  9.720000e+02   977.000000  977.000000
# mean   1.171311e+05  1139.488025    0.000030
# std    8.500866e+04    39.095668    0.005343
# min    0.000000e+00  1054.900000   -0.020400
# 25%    7.668725e+04  1117.900000   -0.003200
# 50%    9.696600e+04  1133.900000    0.000100
# 75%    1.348950e+05  1169.100000    0.003400
# max    1.473645e+06  1243.100000    0.026500

# %% [markdown]
# ## 2. 데이터 준비

# %% [markdown]
# ### 1) 변수 정리

# %%
# NaN 확인
data.isnull().sum()
# Out:
# Date          0
# Open          5
# High          5
# Low           5
# Close         5
# Volume        5
# exch_Close    0
# exch_Diff     0
# dtype: int64

# %%
data['Open'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 972    False
# 973    False
# 974    False
# 975    False
# 976    False
# Name: Open, Length: 977, dtype: bool

# %%
# NaN 행들을 확인
data.loc[data['Open'].isnull()]
# Out:
#            Date  Open  High  Low  Close  Volume  exch_Close  exch_Diff
# 458  2017-11-16   NaN   NaN  NaN    NaN     NaN      1097.2    -0.0077
# 463  2017-11-23   NaN   NaN  NaN    NaN     NaN      1084.0    -0.0019
# 487  2018-01-02   NaN   NaN  NaN    NaN     NaN      1063.2    -0.0032
# 700  2018-11-15   NaN   NaN  NaN    NaN     NaN      1127.9    -0.0042
# 945  2019-11-14   NaN   NaN  NaN    NaN     NaN      1169.1    -0.0021

# %%
# 2019-11-14는 목요일이나 NaN으로 채워져 있음
data.loc[(data['Date']>='2019-11-12')&(data['Date']<='2019-11-20')]
# Out:
#            Date      Open      High       Low     Close    Volume  exch_Close  \
# 943  2019-11-12  271000.0  271000.0  268500.0  269000.0  168608.0      1166.5
# 944  2019-11-13  268000.0  269500.0  261500.0  263000.0  257602.0      1171.5
# 945  2019-11-14       NaN       NaN       NaN       NaN       NaN      1169.1
# 946  2019-11-15  265000.0  270000.0  265000.0  270000.0  198430.0      1163.7
# 947  2019-11-18  270000.0  275000.0  269500.0  275000.0  185370.0      1167.2
# 948  2019-11-19  274500.0  276500.0  272500.0  272500.0  222226.0      1168.4
# 949  2019-11-20  271500.0  274500.0  268500.0  272000.0  210122.0      1170.8
#
#      exch_Diff
# 943     0.0009
# 944     0.0043
# 945    -0.0021
# 946    -0.0046
# 947     0.0031
# 948     0.0010
# 949     0.0021

# %% [markdown]
# ### 2) NaN 처리

# %%
# 방법1 : 행을 제거한다.

data1 = data.dropna(axis=0)
data1.isnull().sum()
# Out:
# Date          0
# Open          0
# High          0
# Low           0
# Close         0
# Volume        0
# exch_Close    0
# exch_Diff     0
# dtype: int64

# %%
data1.loc[(data1['Date']>='2019-11-12')&(data1['Date']<='2019-11-20')]
# Out:
#            Date      Open      High       Low     Close    Volume  exch_Close  \
# 943  2019-11-12  271000.0  271000.0  268500.0  269000.0  168608.0      1166.5
# 944  2019-11-13  268000.0  269500.0  261500.0  263000.0  257602.0      1171.5
# 946  2019-11-15  265000.0  270000.0  265000.0  270000.0  198430.0      1163.7
# 947  2019-11-18  270000.0  275000.0  269500.0  275000.0  185370.0      1167.2
# 948  2019-11-19  274500.0  276500.0  272500.0  272500.0  222226.0      1168.4
# 949  2019-11-20  271500.0  274500.0  268500.0  272000.0  210122.0      1170.8
#
#      exch_Diff
# 943     0.0009
# 944     0.0043
# 946    -0.0046
# 947     0.0031
# 948     0.0010
# 949     0.0021

# %%
# 방법2 : 이전 값으로 채운다. 

data2 = data.fillna(method='ffill')
data2.isnull().sum()
# Out:
# Date          0
# Open          0
# High          0
# Low           0
# Close         0
# Volume        0
# exch_Close    0
# exch_Diff     0
# dtype: int64

# %%
data2.loc[(data2['Date']>='2019-11-12')&(data2['Date']<='2019-11-20')]
# Out:
#            Date      Open      High       Low     Close    Volume  exch_Close  \
# 943  2019-11-12  271000.0  271000.0  268500.0  269000.0  168608.0      1166.5
# 944  2019-11-13  268000.0  269500.0  261500.0  263000.0  257602.0      1171.5
# 945  2019-11-14  268000.0  269500.0  261500.0  263000.0  257602.0      1169.1
# 946  2019-11-15  265000.0  270000.0  265000.0  270000.0  198430.0      1163.7
# 947  2019-11-18  270000.0  275000.0  269500.0  275000.0  185370.0      1167.2
# 948  2019-11-19  274500.0  276500.0  272500.0  272500.0  222226.0      1168.4
# 949  2019-11-20  271500.0  274500.0  268500.0  272000.0  210122.0      1170.8
#
#      exch_Diff
# 943     0.0009
# 944     0.0043
# 945    -0.0021
# 946    -0.0046
# 947     0.0031
# 948     0.0010
# 949     0.0021

# %%
# 방법3 : 앞뒤값의 중간값으로 채우기

data3 = data.interpolate(method='linear') # default는 linear
data3.isnull().sum()
# Out:
# Date          0
# Open          0
# High          0
# Low           0
# Close         0
# Volume        0
# exch_Close    0
# exch_Diff     0
# dtype: int64

# %%
data3.loc[(data3['Date']>='2019-11-12')&(data3['Date']<='2019-11-20')]
# Out:
#            Date      Open      High       Low     Close    Volume  exch_Close  \
# 943  2019-11-12  271000.0  271000.0  268500.0  269000.0  168608.0      1166.5
# 944  2019-11-13  268000.0  269500.0  261500.0  263000.0  257602.0      1171.5
# 945  2019-11-14  266500.0  269750.0  263250.0  266500.0  228016.0      1169.1
# 946  2019-11-15  265000.0  270000.0  265000.0  270000.0  198430.0      1163.7
# 947  2019-11-18  270000.0  275000.0  269500.0  275000.0  185370.0      1167.2
# 948  2019-11-19  274500.0  276500.0  272500.0  272500.0  222226.0      1168.4
# 949  2019-11-20  271500.0  274500.0  268500.0  272000.0  210122.0      1170.8
#
#      exch_Diff
# 943     0.0009
# 944     0.0043
# 945    -0.0021
# 946    -0.0046
# 947     0.0031
# 948     0.0010
# 949     0.0021

# %% [markdown]
# ### 3) Feature Engineering

# %% [markdown]
# - 내일의 주가에 영향을 주는 요인은?

# %%
data2.head()
# Out:
#          Date      Open      High       Low     Close    Volume  exch_Close  \
# 0  2016-01-04  243000.0  245000.0  234500.0  234500.0  173905.0      1190.4
# 1  2016-01-05  236000.0  244000.0  234000.0  241000.0  182985.0      1190.8
# 2  2016-01-06  241000.0  243000.0  237500.0  239000.0  108574.0      1200.5
# 3  2016-01-07  237000.0  243000.0  236000.0  240500.0  113376.0      1197.3
# 4  2016-01-08  240500.0  242500.0  235000.0  241500.0   81557.0      1207.9
#
#    exch_Diff
# 0     0.0127
# 1     0.0004
# 2     0.0082
# 3    -0.0027
# 4     0.0089

# %% [markdown]
# 1) 날짜 데이터 다루기
#
# - 날짜로부터 추가 변수를 도출해내기 위해서 날짜 변수를 생성.
# - 추가 변수 생성이 끝난 후 날짜 변수 제거.

# %%
data2.dtypes
# Out:
# Date           object
# Open          float64
# High          float64
# Low           float64
# Close         float64
# Volume        float64
# exch_Close    float64
# exch_Diff     float64
# dtype: object

# %%
# 문자열 형식을 날짜 형식으로 변환
data2['Date'] = pd.to_datetime(data2['Date'])
print(data2.dtypes)
# Out:
# Date          datetime64[ns]
# Open                 float64
# High                 float64
# Low                  float64
# Close                float64
# Volume               float64
# exch_Close           float64
# exch_Diff            float64
# dtype: object

# %%
# 요일을 추가
data2['WeekDay'] = data2['Date'].dt.dayofweek # 요일 번호
data2.head(10)
# Out:
#         Date      Open      High       Low     Close    Volume  exch_Close  \
# 0 2016-01-04  243000.0  245000.0  234500.0  234500.0  173905.0      1190.4
# 1 2016-01-05  236000.0  244000.0  234000.0  241000.0  182985.0      1190.8
# 2 2016-01-06  241000.0  243000.0  237500.0  239000.0  108574.0      1200.5
# 3 2016-01-07  237000.0  243000.0  236000.0  240500.0  113376.0      1197.3
# 4 2016-01-08  240500.0  242500.0  235000.0  241500.0   81557.0      1207.9
# 5 2016-01-11  238000.0  241500.0  236000.0  239000.0   84152.0      1204.8
# 6 2016-01-12  240000.0  246000.0  237000.0  237500.0   86196.0      1210.3
# 7 2016-01-13  239000.0  245000.0  238000.0  242500.0   90207.0      1210.2
# 8 2016-01-14  239000.0  240500.0  235000.0  240000.0   96090.0      1207.7
# 9 2016-01-15  243500.0  243500.0  234500.0  234500.0   99523.0      1214.8
#
#    exch_Diff  WeekDay
# 0     0.0127        0
# 1     0.0004        1
# 2     0.0082        2
# 3    -0.0027        3
# 4     0.0089        4
# 5    -0.0026        0
# 6     0.0046        1
# 7    -0.0001        2
# 8    -0.0021        3
# 9     0.0059        4

# %%
# 요일 이름으로 다시 추가.
data2['WeekDay'] = data2['Date'].dt.day_name() # 요일 이름
data2.head()
# Out:
#         Date      Open      High       Low     Close    Volume  exch_Close  \
# 0 2016-01-04  243000.0  245000.0  234500.0  234500.0  173905.0      1190.4
# 1 2016-01-05  236000.0  244000.0  234000.0  241000.0  182985.0      1190.8
# 2 2016-01-06  241000.0  243000.0  237500.0  239000.0  108574.0      1200.5
# 3 2016-01-07  237000.0  243000.0  236000.0  240500.0  113376.0      1197.3
# 4 2016-01-08  240500.0  242500.0  235000.0  241500.0   81557.0      1207.9
#
#    exch_Diff    WeekDay
# 0     0.0127     Monday
# 1     0.0004    Tuesday
# 2     0.0082  Wednesday
# 3    -0.0027   Thursday
# 4     0.0089     Friday

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 977 entries, 0 to 976
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        977 non-null    datetime64[ns]
#  1   Open        977 non-null    float64
#  2   High        977 non-null    float64
#  3   Low         977 non-null    float64
#  4   Close       977 non-null    float64
#  5   Volume      977 non-null    float64
#  6   exch_Close  977 non-null    float64
#  7   exch_Diff   977 non-null    float64
#  8   WeekDay     977 non-null    object
# dtypes: datetime64[ns](1), float64(7), object(1)
# memory usage: 76.3+ KB

# %% [markdown]
# 2) 이전 데이터 붙이기
#
# - .shift() : 예) 전날 주가, 전날 환율
# - .rolling() : 예) 7일 이동평균 주가

# %%
# 전날 주가를 추가합니다.
# 기존 값을 한칸 아래로 내린 새로운 열 만들기
data2['Close_lag1'] = data2['Close'].shift() # default = 1
data2.head()
# Out:
#         Date      Open      High       Low     Close    Volume  exch_Close  \
# 0 2016-01-04  243000.0  245000.0  234500.0  234500.0  173905.0      1190.4
# 1 2016-01-05  236000.0  244000.0  234000.0  241000.0  182985.0      1190.8
# 2 2016-01-06  241000.0  243000.0  237500.0  239000.0  108574.0      1200.5
# 3 2016-01-07  237000.0  243000.0  236000.0  240500.0  113376.0      1197.3
# 4 2016-01-08  240500.0  242500.0  235000.0  241500.0   81557.0      1207.9
#
#    exch_Diff    WeekDay  Close_lag1
# 0     0.0127     Monday         NaN
# 1     0.0004    Tuesday    234500.0
# 2     0.0082  Wednesday    241000.0
# 3    -0.0027   Thursday    239000.0
# 4     0.0089     Friday    240500.0

# %%
# 7일 이동최대값 주가
# min_periods가 1이기 때문에 첫칸부터 연산값이 채워짐.
data2['Close_MA7_lag1'] = data2['Close'].rolling(7, min_periods=1).max()
data2.head()
# Out:
#         Date      Open      High       Low     Close    Volume  exch_Close  \
# 0 2016-01-04  243000.0  245000.0  234500.0  234500.0  173905.0      1190.4
# 1 2016-01-05  236000.0  244000.0  234000.0  241000.0  182985.0      1190.8
# 2 2016-01-06  241000.0  243000.0  237500.0  239000.0  108574.0      1200.5
# 3 2016-01-07  237000.0  243000.0  236000.0  240500.0  113376.0      1197.3
# 4 2016-01-08  240500.0  242500.0  235000.0  241500.0   81557.0      1207.9
#
#    exch_Diff    WeekDay  Close_lag1  Close_MA7_lag1
# 0     0.0127     Monday         NaN        234500.0
# 1     0.0004    Tuesday    234500.0        241000.0
# 2     0.0082  Wednesday    241000.0        241000.0
# 3    -0.0027   Thursday    239000.0        241000.0
# 4     0.0089     Friday    240500.0        241500.0

# %%
# 7일 이동평균 주가
data2['Close_MA7_lag1'] = data2['Close'].rolling(7, min_periods=1).mean()
data2.head()
# Out:
#         Date      Open      High       Low     Close    Volume  exch_Close  \
# 0 2016-01-04  243000.0  245000.0  234500.0  234500.0  173905.0      1190.4
# 1 2016-01-05  236000.0  244000.0  234000.0  241000.0  182985.0      1190.8
# 2 2016-01-06  241000.0  243000.0  237500.0  239000.0  108574.0      1200.5
# 3 2016-01-07  237000.0  243000.0  236000.0  240500.0  113376.0      1197.3
# 4 2016-01-08  240500.0  242500.0  235000.0  241500.0   81557.0      1207.9
#
#    exch_Diff    WeekDay  Close_lag1  Close_MA7_lag1
# 0     0.0127     Monday         NaN   234500.000000
# 1     0.0004    Tuesday    234500.0   237750.000000
# 2     0.0082  Wednesday    241000.0   238166.666667
# 3    -0.0027   Thursday    239000.0   238750.000000
# 4     0.0089     Friday    240500.0   239300.000000

# %%
data2['Close_MA7_lag1'] = data2['Close'].rolling(7, min_periods=1).mean().shift()
data2.head()
# Out:
#         Date      Open      High       Low     Close    Volume  exch_Close  \
# 0 2016-01-04  243000.0  245000.0  234500.0  234500.0  173905.0      1190.4
# 1 2016-01-05  236000.0  244000.0  234000.0  241000.0  182985.0      1190.8
# 2 2016-01-06  241000.0  243000.0  237500.0  239000.0  108574.0      1200.5
# 3 2016-01-07  237000.0  243000.0  236000.0  240500.0  113376.0      1197.3
# 4 2016-01-08  240500.0  242500.0  235000.0  241500.0   81557.0      1207.9
#
#    exch_Diff    WeekDay  Close_lag1  Close_MA7_lag1
# 0     0.0127     Monday         NaN             NaN
# 1     0.0004    Tuesday    234500.0   234500.000000
# 2     0.0082  Wednesday    241000.0   237750.000000
# 3    -0.0027   Thursday    239000.0   238166.666667
# 4     0.0089     Friday    240500.0   238750.000000

# %% [markdown]
# 3) 월 데이터 추가

# %%
data2['Month'] = data2['Date'].dt.month
data2.head()
# Out:
#         Date      Open      High       Low     Close    Volume  exch_Close  \
# 0 2016-01-04  243000.0  245000.0  234500.0  234500.0  173905.0      1190.4
# 1 2016-01-05  236000.0  244000.0  234000.0  241000.0  182985.0      1190.8
# 2 2016-01-06  241000.0  243000.0  237500.0  239000.0  108574.0      1200.5
# 3 2016-01-07  237000.0  243000.0  236000.0  240500.0  113376.0      1197.3
# 4 2016-01-08  240500.0  242500.0  235000.0  241500.0   81557.0      1207.9
#
#    exch_Diff    WeekDay  Close_lag1  Close_MA7_lag1  Month
# 0     0.0127     Monday         NaN             NaN      1
# 1     0.0004    Tuesday    234500.0   234500.000000      1
# 2     0.0082  Wednesday    241000.0   237750.000000      1
# 3    -0.0027   Thursday    239000.0   238166.666667      1
# 4     0.0089     Friday    240500.0   238750.000000      1

# %% [markdown]
# 4) 전날 거개량 컬럼, 전날 환율 증감 컬럼

# %%
data2['Vol_lag1'] = data2['Volume'].shift(1)
data2['exch_lag1'] = data2['exch_Diff'].shift(1)

data2.head()
# Out:
#         Date      Open      High       Low     Close    Volume  exch_Close  \
# 0 2016-01-04  243000.0  245000.0  234500.0  234500.0  173905.0      1190.4
# 1 2016-01-05  236000.0  244000.0  234000.0  241000.0  182985.0      1190.8
# 2 2016-01-06  241000.0  243000.0  237500.0  239000.0  108574.0      1200.5
# 3 2016-01-07  237000.0  243000.0  236000.0  240500.0  113376.0      1197.3
# 4 2016-01-08  240500.0  242500.0  235000.0  241500.0   81557.0      1207.9
#
#    exch_Diff    WeekDay  Close_lag1  Close_MA7_lag1  Month  Vol_lag1  \
# 0     0.0127     Monday         NaN             NaN      1       NaN
# 1     0.0004    Tuesday    234500.0   234500.000000      1  173905.0
# 2     0.0082  Wednesday    241000.0   237750.000000      1  182985.0
# 3    -0.0027   Thursday    239000.0   238166.666667      1  108574.0
# 4     0.0089     Friday    240500.0   238750.000000      1  113376.0
#
#    exch_lag1
# 0        NaN
# 1     0.0127
# 2     0.0004
# 3     0.0082
# 4    -0.0027

# %% [markdown]
# 5) 전날 주가 - 전전날 주가 컬럼

# %%
data2['Close_diff'] = data2['Close_lag1'] - data2['Close'].shift(2)

data2.head()
# Out:
#         Date      Open      High       Low     Close    Volume  exch_Close  \
# 0 2016-01-04  243000.0  245000.0  234500.0  234500.0  173905.0      1190.4
# 1 2016-01-05  236000.0  244000.0  234000.0  241000.0  182985.0      1190.8
# 2 2016-01-06  241000.0  243000.0  237500.0  239000.0  108574.0      1200.5
# 3 2016-01-07  237000.0  243000.0  236000.0  240500.0  113376.0      1197.3
# 4 2016-01-08  240500.0  242500.0  235000.0  241500.0   81557.0      1207.9
#
#    exch_Diff    WeekDay  Close_lag1  Close_MA7_lag1  Month  Vol_lag1  \
# 0     0.0127     Monday         NaN             NaN      1       NaN
# 1     0.0004    Tuesday    234500.0   234500.000000      1  173905.0
# 2     0.0082  Wednesday    241000.0   237750.000000      1  182985.0
# 3    -0.0027   Thursday    239000.0   238166.666667      1  108574.0
# 4     0.0089     Friday    240500.0   238750.000000      1  113376.0
#
#    exch_lag1  Close_diff
# 0        NaN         NaN
# 1     0.0127         NaN
# 2     0.0004      6500.0
# 3     0.0082     -2000.0
# 4    -0.0027      1500.0

# %%
data2['Close_diff'] = data2['Close_lag1'] - data2['Close_lag1'].shift()

data2.head()
# Out:
#         Date      Open      High       Low     Close    Volume  exch_Close  \
# 0 2016-01-04  243000.0  245000.0  234500.0  234500.0  173905.0      1190.4
# 1 2016-01-05  236000.0  244000.0  234000.0  241000.0  182985.0      1190.8
# 2 2016-01-06  241000.0  243000.0  237500.0  239000.0  108574.0      1200.5
# 3 2016-01-07  237000.0  243000.0  236000.0  240500.0  113376.0      1197.3
# 4 2016-01-08  240500.0  242500.0  235000.0  241500.0   81557.0      1207.9
#
#    exch_Diff    WeekDay  Close_lag1  Close_MA7_lag1  Month  Vol_lag1  \
# 0     0.0127     Monday         NaN             NaN      1       NaN
# 1     0.0004    Tuesday    234500.0   234500.000000      1  173905.0
# 2     0.0082  Wednesday    241000.0   237750.000000      1  182985.0
# 3    -0.0027   Thursday    239000.0   238166.666667      1  108574.0
# 4     0.0089     Friday    240500.0   238750.000000      1  113376.0
#
#    exch_lag1  Close_diff
# 0        NaN         NaN
# 1     0.0127         NaN
# 2     0.0004      6500.0
# 3     0.0082     -2000.0
# 4    -0.0027      1500.0

# %% [markdown]
# 6) 전날 종가 - 전날 시가 컬럼

# %%
data2['Close-Open'] = data2['Close'].shift() - data2['Open'].shift()

data2.head()
# Out:
#         Date      Open      High       Low     Close    Volume  exch_Close  \
# 0 2016-01-04  243000.0  245000.0  234500.0  234500.0  173905.0      1190.4
# 1 2016-01-05  236000.0  244000.0  234000.0  241000.0  182985.0      1190.8
# 2 2016-01-06  241000.0  243000.0  237500.0  239000.0  108574.0      1200.5
# 3 2016-01-07  237000.0  243000.0  236000.0  240500.0  113376.0      1197.3
# 4 2016-01-08  240500.0  242500.0  235000.0  241500.0   81557.0      1207.9
#
#    exch_Diff    WeekDay  Close_lag1  Close_MA7_lag1  Month  Vol_lag1  \
# 0     0.0127     Monday         NaN             NaN      1       NaN
# 1     0.0004    Tuesday    234500.0   234500.000000      1  173905.0
# 2     0.0082  Wednesday    241000.0   237750.000000      1  182985.0
# 3    -0.0027   Thursday    239000.0   238166.666667      1  108574.0
# 4     0.0089     Friday    240500.0   238750.000000      1  113376.0
#
#    exch_lag1  Close_diff  Close-Open
# 0        NaN         NaN         NaN
# 1     0.0127         NaN     -8500.0
# 2     0.0004      6500.0      5000.0
# 3     0.0082     -2000.0     -2000.0
# 4    -0.0027      1500.0      3500.0

# %% [markdown]
# ### 4) Dummy Variable
#
# - 범주형 변수를 숫자로 만드는 방법
# - pd.get_dummies, pd.concat, drop
# - 불필요한 컬럼들 제거

# %%
# dummy variable
dumm_weekday = pd.get_dummies(data2['WeekDay'], drop_first=True, prefix='day')
dumm_weekday.head()
# Out:
#    day_Monday  day_Thursday  day_Tuesday  day_Wednesday
# 0           1             0            0              0
# 1           0             0            1              0
# 2           0             0            0              1
# 3           0             1            0              0
# 4           0             0            0              0

# %%
dumm_weekday = pd.get_dummies(data2['WeekDay'], drop_first=True)
dumm_weekday.head()
# Out:
#    Monday  Thursday  Tuesday  Wednesday
# 0       1         0        0          0
# 1       0         0        1          0
# 2       0         0        0          1
# 3       0         1        0          0
# 4       0         0        0          0

# %%
data3 = pd.concat([data2, dumm_weekday], axis=1)
data3.head()
# Out:
#         Date      Open      High       Low     Close    Volume  exch_Close  \
# 0 2016-01-04  243000.0  245000.0  234500.0  234500.0  173905.0      1190.4
# 1 2016-01-05  236000.0  244000.0  234000.0  241000.0  182985.0      1190.8
# 2 2016-01-06  241000.0  243000.0  237500.0  239000.0  108574.0      1200.5
# 3 2016-01-07  237000.0  243000.0  236000.0  240500.0  113376.0      1197.3
# 4 2016-01-08  240500.0  242500.0  235000.0  241500.0   81557.0      1207.9
#
#    exch_Diff    WeekDay  Close_lag1  Close_MA7_lag1  Month  Vol_lag1  \
# 0     0.0127     Monday         NaN             NaN      1       NaN
# 1     0.0004    Tuesday    234500.0   234500.000000      1  173905.0
# 2     0.0082  Wednesday    241000.0   237750.000000      1  182985.0
# 3    -0.0027   Thursday    239000.0   238166.666667      1  108574.0
# 4     0.0089     Friday    240500.0   238750.000000      1  113376.0
#
#    exch_lag1  Close_diff  Close-Open  Monday  Thursday  Tuesday  Wednesday
# 0        NaN         NaN         NaN       1         0        0          0
# 1     0.0127         NaN     -8500.0       0         0        1          0
# 2     0.0004      6500.0      5000.0       0         0        0          1
# 3     0.0082     -2000.0     -2000.0       0         1        0          0
# 4    -0.0027      1500.0      3500.0       0         0        0          0

# %%
# 컬럼 삭제
drop_x = ['Date','Open','High','Low','Volume','exch_Close','exch_Diff','WeekDay']
data3.drop(drop_x, axis = 1, inplace = True)
data3.head()
# Out:
#       Close  Close_lag1  Close_MA7_lag1  Month  Vol_lag1  exch_lag1  \
# 0  234500.0         NaN             NaN      1       NaN        NaN
# 1  241000.0    234500.0   234500.000000      1  173905.0     0.0127
# 2  239000.0    241000.0   237750.000000      1  182985.0     0.0004
# 3  240500.0    239000.0   238166.666667      1  108574.0     0.0082
# 4  241500.0    240500.0   238750.000000      1  113376.0    -0.0027
#
#    Close_diff  Close-Open  Monday  Thursday  Tuesday  Wednesday
# 0         NaN         NaN       1         0        0          0
# 1         NaN     -8500.0       0         0        1          0
# 2      6500.0      5000.0       0         0        0          1
# 3     -2000.0     -2000.0       0         1        0          0
# 4      1500.0      3500.0       0         0        0          0

# %%
# shift를 하다보내 행에 NaN이 다시 들어갔습니다. dropna로 제거합시다.
data3 = data3.dropna(axis = 0)
data3.head()
# Out:
#       Close  Close_lag1  Close_MA7_lag1  Month  Vol_lag1  exch_lag1  \
# 2  239000.0    241000.0   237750.000000      1  182985.0     0.0004
# 3  240500.0    239000.0   238166.666667      1  108574.0     0.0082
# 4  241500.0    240500.0   238750.000000      1  113376.0    -0.0027
# 5  239000.0    241500.0   239300.000000      1   81557.0     0.0089
# 6  237500.0    239000.0   239250.000000      1   84152.0    -0.0026
#
#    Close_diff  Close-Open  Monday  Thursday  Tuesday  Wednesday
# 2      6500.0      5000.0       0         0        0          1
# 3     -2000.0     -2000.0       0         1        0          0
# 4      1500.0      3500.0       0         0        0          0
# 5      1000.0      1000.0       1         0        0          0
# 6     -2500.0      1000.0       0         0        1          0

# %% [markdown]
# ### 5) Data Split
#
# - sklearn의 데이터 분할 함수 사용
#     - 요인, x, feature, 조작변수, 통제변수, 리스크벡터, Input, 독립변수
#     - 결과, y, target, label, Output, 종속변수

# %%
from sklearn.model_selection import train_test_split

# %%
# features와 target 분리
X = data3.drop('Close', axis=1)
y = data3.iloc[:, 0]

# %%
# train : test = 7 : 3
train_x, test_x, train_y, test_y = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
train_x.shape, train_y.shape
# Out:
# ((682, 11), (682,))

# %% [markdown]
# ### 6) Scaling features

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# 사용할 함수 선언
scaler = MinMaxScaler()

# %%
# 함수를 만들고
#scaler.fit(train_x)

# 변환시키기
#train_x = scaler.transform(train_x)

train_x = scaler.fit_transform(train_x)
test_x = scaler.transform(test_x)

# %%
pd.DataFrame(train_x).describe()
# Out:
#                0           1           2           3           4           5   \
# count  682.000000  682.000000  682.000000  682.000000  682.000000  682.000000
# mean     0.438411    0.455170    0.495734    0.103815    0.434030    0.479434
# std      0.214321    0.232798    0.310865    0.069850    0.115929    0.109440
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.258272    0.252746    0.181818    0.068378    0.365139    0.421053
# 50%      0.474265    0.490173    0.454545    0.086258    0.437100    0.473684
# 75%      0.595588    0.628613    0.727273    0.118671    0.507463    0.539474
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#                6           7           8           9           10
# count  682.000000  682.000000  682.000000  682.000000  682.000000
# mean     0.488208    0.195015    0.196481    0.186217    0.217009
# std      0.108574    0.396503    0.397628    0.389567    0.412511
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.422535    0.000000    0.000000    0.000000    0.000000
# 50%      0.478873    0.000000    0.000000    0.000000    0.000000
# 75%      0.549296    0.000000    0.000000    0.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000
